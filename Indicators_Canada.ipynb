# %% [markdown]
# <a href="https://colab.research.google.com/github/marcia-lopes/Data-Analysis/blob/main/Indicators_Canada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Getting the data**

# %%
df = pd.read_excel("C:\\Users\\Márcia Laptop\\Documents\\Indicators_Canada.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-5efb43a458c8> in <module>
# ----> 1 df = pd.read_excel("C:\\Users\\Márcia Laptop\\Documents\\Indicators_Canada.xlsx")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d91e10cf-23be-4f6b-bc19-057c278253a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d91e10cf-23be-4f6b-bc19-057c278253a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_excel(io.BytesIO(uploaded["Indicators_Canada.xlsx"]))

# %%
df.head()
# Out:
#                                           Indicators      2015      2016  \
# 0          Perceived health, very good or excellent   18759800  18714100
# 1                    Perceived health, fair or poor    3244200   3443000
# 2   Perceived mental health, very good or excellent   21347700  21023500
# 3             Perceived mental health, fair or poor    1732100   2053000
# 4  Perceived life stress, most days quite a bit o...   6475700   6564200
#
#        2017      2018      2019      2020      2021
# 0  18885900  19024300  19464600  20106900  19416200
# 1   3460600   3464300   3464200   3428300   3702600
# 2  21055100  20850600  20701100  20243300  18653600
# 3   2110500   2339400   2494800   3021900   3713700
# 4   6694300   6573900   6729400   6560500   6605100

# %%
df.shape
# Out:
# (24, 8)

# %%
df.columns
# Out:
# Index(['Indicators', 2015, 2016, 2017, 2018, 2019, 2020, 2021], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Indicators  24 non-null     object
#  1   2015        24 non-null     object
#  2   2016        24 non-null     object
#  3   2017        24 non-null     object
#  4   2018        24 non-null     object
#  5   2019        24 non-null     object
#  6   2020        24 non-null     object
#  7   2021        24 non-null     object
# dtypes: object(8)
# memory usage: 1.6+ KB

# %%
df.describe()
# Out:
#                                        Indicators 2015 2016 2017 2018 2019  \
# count                                          24   24   24   24   24   24
# unique                                         24   23   23   22   21   21
# top     Perceived health, very good or excellent    ..   ..   ..   ..   ..
# freq                                            1    2    2    3    4    4
#
#        2020 2021
# count    24   24
# unique   23   22
# top      ..   ..
# freq      2    3

# %%
df = df.T

# %%
df.head()
# Out:
#                                                    0   \
# Indicators  Perceived health, very good or excellent
# 2015                                         18759800
# 2016                                         18714100
# 2017                                         18885900
# 2018                                         19024300
#
#                                          1   \
# Indicators  Perceived health, fair or poor
# 2015                                3244200
# 2016                                3443000
# 2017                                3460600
# 2018                                3464300
#
#                                                           2   \
# Indicators  Perceived mental health, very good or excellent
# 2015                                                21347700
# 2016                                                21023500
# 2017                                                21055100
# 2018                                                20850600
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                    0   \
# Indicators  Perceived health, very good or excellent
# 2015                                         18759800
# 2016                                         18714100
# 2017                                         18885900
# 2018                                         19024300
# 2019                                         19464600
# 2020                                         20106900
# 2021                                         19416200
#
#                                          1   \
# Indicators  Perceived health, fair or poor
# 2015                                3244200
# 2016                                3443000
# 2017                                3460600
# 2018                                3464300
# 2019                                3464200
# 2020                                3428300
# 2021                                3702600
#
# ...

# %%
df.describe()
# Out:
#                                                0   \
# count                                           8
# unique                                          8
# top     Perceived health, very good or excellent
# freq                                            1
#
#                                      1   \
# count                                 8
# unique                                8
# top     Perceived health, fair or poor
# freq                                  1
#
#                                                       2   \
# count                                                  8
# unique                                                 8
# top     Perceived mental health, very good or excellent
# freq                                                   1
#
#                                             3   \
# count                                        8
# unique                                       8
# top     Perceived mental health, fair or poor
# ...

# %%
df.shape
# Out:
# (8, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, Indicators to 2021
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       8 non-null      object
#  1   1       8 non-null      object
#  2   2       8 non-null      object
#  3   3       8 non-null      object
#  4   4       8 non-null      object
#  5   5       8 non-null      object
#  6   6       8 non-null      object
#  7   7       8 non-null      object
#  8   8       8 non-null      object
#  9   9       8 non-null      object
#  10  10      8 non-null      object
#  11  11      8 non-null      object
#  12  12      8 non-null      object
#  13  13      8 non-null      object
#  14  14      8 non-null      object
#  15  15      8 non-null      object
#  16  16      8 non-null      object
#  17  17      8 non-null      object
#  18  18      8 non-null      object
#  19  19      8 non-null      object
#  20  20      8 non-null      object
# ...

# %%
df[6].describe()
# Out:
# count          8
# unique         8
# top       Obese
# freq           1
# Name: 6, dtype: object

# %%
df = df.rename(columns=df.iloc[0]).drop(df.index[0])

# %%
df.head()
# Out:
#      Perceived health, very good or excellent   \
# 2015                                  18759800
# 2016                                  18714100
# 2017                                  18885900
# 2018                                  19024300
# 2019                                  19464600
#
#      Perceived health, fair or poor   \
# 2015                         3244200
# 2016                         3443000
# 2017                         3460600
# 2018                         3464300
# 2019                         3464200
#
#      Perceived mental health, very good or excellent   \
# 2015                                         21347700
# 2016                                         21023500
# 2017                                         21055100
# 2018                                         20850600
# 2019                                         20701100
#
#      Perceived mental health, fair or poor   \
# 2015                                1732100
# ...

# %%
df.describe()
# Out:
#         Perceived health, very good or excellent   \
# count                                           7
# unique                                          7
# top                                      18759800
# freq                                            1
#
#         Perceived health, fair or poor   \
# count                                 7
# unique                                7
# top                             3244200
# freq                                  1
#
#         Perceived mental health, very good or excellent   \
# count                                                  7
# unique                                                 7
# top                                             21347700
# freq                                                   1
#
#         Perceived mental health, fair or poor   \
# count                                        7
# unique                                       7
# top                                    1732100
# ...

# %%
df.columns
# Out:
# Index(['Perceived health, very good or excellent ',
#        'Perceived health, fair or poor ',
#        'Perceived mental health, very good or excellent ',
#        'Perceived mental health, fair or poor ',
#        'Perceived life stress, most days quite a bit or extremely stressful ',
#        'Overweight ', 'Obese ', 'Diabetes 23', 'Asthma 24 25',
#        'High blood pressure', 'Mood disorder',
#        'Current smoker, daily or occasional ', 'Current smoker, daily 3',
#        'Cannabis use, past 12 months ',
#        'Cannabis frequency of use in the past months, daily or almost daily',
#        'Heavy drinking ',
#        'Self-reported physical activity, 150 minutes per week',
#        'Exclusive breastfeeding, at least 6 months ',
#        'Fruit and vegetable consumption, 5 times or more per day ',
#        'Sense of belonging to local community, somewhat strong or very strong ',
#        'Life satisfaction, satisfied or very satisfied ',
# ...

# %%
df['Obese '].describe()
# Out:
# count           7
# unique          7
# top       6885600
# freq            1
# Name: Obese , dtype: int64

# %%
df['Obese '].mean()
# Out:
# 7450871.428571428

# %%
df['Obese '].plot()

# %%
df['Overweight '].plot()

# %%
df['Obese '].plot.bar()

# %%
df['Heavy drinking '].plot()

# %%
df['Perceived health, fair or poor '].plot()

# %%
df['Perceived health, very good or excellent '].plot()

# %%
df['Perceived mental health, fair or poor '].plot()

# %%
df['Perceived mental health, very good or excellent '].plot()
